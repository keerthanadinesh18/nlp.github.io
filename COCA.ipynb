# %% [markdown]
# # DEMONSTRATE COCA

# %%
from PIL import Image
img = Image.open(r'E:\\DEEP LEARNING\\chartcorpus.png')
img1 = Image.open(r'E:\\DEEP LEARNING\\corpus1.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1197x388 at 0x19CF79FAA58>

# %%
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1203x541 at 0x19CF79FA860>
