# %% [markdown]
# # ENTITY DETECTION

# %%
import en_core_web_sm

# load en_core_web_sm of English for vocabluary, syntax & entities
nlp = en_core_web_sm.load()

# %%
#for visualization of Entity detection importing displacy from spacy:
import spacy
from spacy import displacy


nytimes= nlp(u"""The prehistory of the United States started with the arrival of Native Americans before 15,000 BC.Numerous indigenous cultures formed, and many disappeared before 1500. The arrival of Christopher Columbus in the year 1492 started the European colonization of the Americas. 
Most colonies were formed after 1600, and the early records and writings of John Winthrop make the United States the first nation whose most distant origins are fully recorded.
By the 1760s, the thirteen British colonies contained 2.5 million people along the Atlantic Coast east of the Appalachian Mountains. After defeating France, the British government imposed a series of taxes, including the Stamp Act of 1765, rejecting the colonists' constitutional argument that new taxes needed their approval. 
Resistance to these taxes, especially the Boston Tea Party in 1773, led to Parliament issuing punitive laws designed to end self-government in Massachusetts.""")

entities=[(i, i.label_, i.label) for i in nytimes.ents]
entities
# Out:
# [(the United States, 'GPE', 384),
#  (Native Americans, 'NORP', 381),
#  (15,000, 'CARDINAL', 397),
#  (1500, 'CARDINAL', 397),
#  (Christopher Columbus, 'PERSON', 380),
#  (the year 1492, 'DATE', 391),
#  (European, 'NORP', 381),
#  (Americas, 'LOC', 385),
#  (1600, 'DATE', 391),
#  (John Winthrop, 'PERSON', 380),
#  (the United States, 'GPE', 384),
#  (first, 'ORDINAL', 396),
#  (the 1760s, 'DATE', 391),
#  (thirteen, 'CARDINAL', 397),
#  (British, 'NORP', 381),
#  (2.5 million, 'CARDINAL', 397),
#  (the Atlantic Coast, 'LOC', 385),
#  (the Appalachian Mountains, 'LOC', 385),
#  (France, 'GPE', 384),
#  (British, 'NORP', 381),
#  (the Stamp Act, 'LAW', 390),
#  (1765, 'DATE', 391),
#  (the Boston Tea Party, 'ORG', 383),
#  (1773, 'DATE', 391),
#  (Parliament, 'ORG', 383),
#  (Massachusetts, 'GPE', 384)]

# %%
displacy.render(nytimes, style = "ent",jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The prehistory of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  started with the arrival of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Native Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  before
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15,000
# ...

# %% [markdown]
# # DEPENDECY PARSING

# %%
docp = nlp (""" Mr. Howbridge, who was named the guardian of the girls, managed matters
for them and saw to it that Ruth, Agnes, Dot and Tess were safely
domiciled in the Corner House.""")

for chunk in docp.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, chunk.root.head.text)
# Out:
#  Mr. Howbridge Howbridge ROOT Howbridge
# who who nsubjpass named
# the girls girls pobj of
# managed matters matters appos Howbridge
# them them pobj for
# it it pobj to
# Ruth Ruth nsubjpass domiciled
# Agnes Agnes conj Ruth
# Dot Dot conj Agnes
# Tess Tess conj Dot
# the Corner House House pobj in

# %%
displacy.render(docp, style="dep", jupyter= True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a6c31ab3ce1c4e5398751cbf7dcffa7d-0" class="displacy" width="6000" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Mr.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
# ...
